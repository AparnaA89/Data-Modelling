# %%
import pandas as pd
from pandas import DataFrame, read_excel, merge
import numpy as np
import matplotlib.pyplot as plt
#import rex
from collections import OrderedDict
import seaborn as sns
import matplotlib as mt

# %%
data = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated.csv', encoding="utf-8")

# %%
#data.dtypes

# %%
data['end']=data['end'].astype(str)
data['left_bottom']=data['left_bottom'].astype(str)
data['mid_point']=data['mid_point'].astype(str)
data['right_bottom']=data['right_bottom'].astype(str)
data['start_point']=data['start_point'].astype(str)
data['end1']=data['end1'].astype(str)
data['left_bottom1']=data['left_bottom1'].astype(str)
data['mid_point1']=data['mid_point1'].astype(str)
data['right_bottom1']=data['right_bottom1'].astype(str)
data['start_point1']=data['start_point1'].astype(str)
data['end2']=data['end2'].astype(str)
data['left_bottom2']=data['left_bottom2'].astype(str)
data['mid_point2']=data['mid_point2'].astype(str)
data['right_bottom2']=data['right_bottom2'].astype(str)
data['start_point2']=data['start_point2'].astype(str)
data['end3']=data['end3'].astype(str)
data['left_bottom3']=data['left_bottom3'].astype(str)
data['mid_point3']=data['mid_point3'].astype(str)
data['right_bottom3']=data['right_bottom3'].astype(str)
data['start_point3']=data['start_point3'].astype(str)

# %%
data['x']=data['end']+","+data['left_bottom']+","+data['mid_point']+","+data['right_bottom']+","+data['start_point']+","+data['end1']+","+data['left_bottom1']+","+data['mid_point1']+","+data['right_bottom1']+","+data['start_point1']+","+data['end2']+","+data['left_bottom2']+","+data['mid_point2']+","+data['right_bottom2']+","+data['start_point2']+","+data['end3']+","+data['left_bottom3']+","+data['mid_point3']+","+data['right_bottom3']+","+data['start_point3']
data = data.drop(columns=['Unnamed: 0'])
data1=data[["x"]]
data1.to_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv')
data11 = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv', encoding = "utf-8")
data11 = data11.drop(columns=['Unnamed: 0'])
data11
# Out:
#                                                    x
# 0  1478563200000,1473638400000,1476057600000,1476...
# 1  1528675200000,1522195200000,1524009600000,1524...
# 2  1517961600000,1512604800000,1513296000000,1513...
# 3  1501027200000,1496188800000,1498176000000,1499...
# 4  1531785600000,1525824000000,1528675200000,1528...

# %%
data2 = pd.DataFrame(data11)
data2["first_x"] = data2["x"][0]
#data2["first_y"] = data2["y"][0]
data2["first_x"][1:4] = ""
#data2["first_y"][1:4] = ""
data2["x"].apply(lambda x: len(x.split(',')))
data3 = data2.drop(columns=['x'])
data3
#data2['comma_count'] = data2.x.str.count(',')
#data2['comma_count'][0]
# Out:
#                                              first_x
# 0  1478563200000,1473638400000,1476057600000,1476...
# 1
# 2
# 3
# 4  1478563200000,1473638400000,1476057600000,1476...

# %%
newx = data3["first_x"].str.split(",", n =19, expand = True)
#newy = data3["first_y"].str.split(",", n =4, expand = True)
data3["x_0"] = pd.to_numeric(newx[0])
data3["x_1"] = pd.to_numeric(newx[1])
data3["x_2"] = pd.to_numeric(newx[2])
data3["x_3"] = pd.to_numeric(newx[3])
data3["x_4"] = pd.to_numeric(newx[4])
data3["x_5"] = pd.to_numeric(newx[5])
data3["x_6"] = pd.to_numeric(newx[6])
data3["x_7"] = pd.to_numeric(newx[7])
data3["x_8"] = pd.to_numeric(newx[8])
data3["x_9"] = pd.to_numeric(newx[9])
data3["xx_1"] = pd.to_numeric(newx[10])
data3["xx_2"] = pd.to_numeric(newx[11])
data3["xx_3"] = pd.to_numeric(newx[12])
data3["xx_4"] = pd.to_numeric(newx[13])
data3["xx_5"] = pd.to_numeric(newx[14])
data3["xx_6"] = pd.to_numeric(newx[15])
data3["xx_7"] = pd.to_numeric(newx[16])
data3["xx_8"] = pd.to_numeric(newx[17])
data3["xx_9"] = pd.to_numeric(newx[18])
data3["xxx_1"] = pd.to_numeric(newx[19])

# %%
#data3

# %%
data3 = data3.melt(id_vars = ["first_x"],
                 var_name = "xx",
                 value_name = "Value")

data3 = data3.sort_values(by = ["xx"])
data3 = data3.mask(data3.eq('None')).dropna()
data3['Value'].replace('',np.nan, inplace=True)
data3.dropna(subset=['Value'], inplace = True)
data3
# Out:
#                                               first_x     xx         Value
# 0   1478563200000,1473638400000,1476057600000,1476...    x_0  1.478563e+12
# 4   1478563200000,1473638400000,1476057600000,1476...    x_0  1.478563e+12
# 5   1478563200000,1473638400000,1476057600000,1476...    x_1  1.473638e+12
# 9   1478563200000,1473638400000,1476057600000,1476...    x_1  1.473638e+12
# 14  1478563200000,1473638400000,1476057600000,1476...    x_2  1.476058e+12
# 10  1478563200000,1473638400000,1476057600000,1476...    x_2  1.476058e+12
# 15  1478563200000,1473638400000,1476057600000,1476...    x_3  1.476317e+12
# 19  1478563200000,1473638400000,1476057600000,1476...    x_3  1.476317e+12
# 24  1478563200000,1473638400000,1476057600000,1476...    x_4  1.472515e+12
# 20  1478563200000,1473638400000,1476057600000,1476...    x_4  1.472515e+12
# 25  1478563200000,1473638400000,1476057600000,1476...    x_5  1.520899e+12
# 29  1478563200000,1473638400000,1476057600000,1476...    x_5  1.520899e+12
# 34  1478563200000,1473638400000,1476057600000,1476...    x_6  1.518134e+12
# 30  1478563200000,1473638400000,1476057600000,1476...    x_6  1.518134e+12
# 35  1478563200000,1473638400000,1476057600000,1476...    x_7  1.519085e+12
# 39  1478563200000,1473638400000,1476057600000,1476...    x_7  1.519085e+12
# 40  1478563200000,1473638400000,1476057600000,1476...    x_8  1.520467e+12
# 44  1478563200000,1473638400000,1476057600000,1476...    x_8  1.520467e+12
# 49  1478563200000,1473638400000,1476057600000,1476...    x_9  1.515110e+12
# 45  1478563200000,1473638400000,1476057600000,1476...    x_9  1.515110e+12
# 50  1478563200000,1473638400000,1476057600000,1476...   xx_1  1.529021e+12
# 54  1478563200000,1473638400000,1476057600000,1476...   xx_1  1.529021e+12
# 59  1478563200000,1473638400000,1476057600000,1476...   xx_2  1.525306e+12
# 55  1478563200000,1473638400000,1476057600000,1476...   xx_2  1.525306e+12
# 60  1478563200000,1473638400000,1476057600000,1476...   xx_3  1.526256e+12
# 64  1478563200000,1473638400000,1476057600000,1476...   xx_3  1.526256e+12
# 65  1478563200000,1473638400000,1476057600000,1476...   xx_4  1.526861e+12
# 69  1478563200000,1473638400000,1476057600000,1476...   xx_4  1.526861e+12
# 74  1478563200000,1473638400000,1476057600000,1476...   xx_5  1.523923e+12
# 70  1478563200000,1473638400000,1476057600000,1476...   xx_5  1.523923e+12
# 75  1478563200000,1473638400000,1476057600000,1476...   xx_6  1.544746e+12
# 79  1478563200000,1473638400000,1476057600000,1476...   xx_6  1.544746e+12
# 80  1478563200000,1473638400000,1476057600000,1476...   xx_7  1.540512e+12
# 84  1478563200000,1473638400000,1476057600000,1476...   xx_7  1.540512e+12
# 89  1478563200000,1473638400000,1476057600000,1476...   xx_8  1.541635e+12
# 85  1478563200000,1473638400000,1476057600000,1476...   xx_8  1.541635e+12
# 90  1478563200000,1473638400000,1476057600000,1476...   xx_9  1.544054e+12
# 94  1478563200000,1473638400000,1476057600000,1476...   xx_9  1.544054e+12
# 95  1478563200000,1473638400000,1476057600000,1476...  xxx_1  1.538352e+12
# 99  1478563200000,1473638400000,1476057600000,1476...  xxx_1  1.538352e+12

# %%
data3["xx"].value_counts()
graph_x = data3['Value'][0:36].tolist()
fig= plt.figure(figsize=(10, 5))
plt.title("Double Bottom")
plt.xticks(rotation=90)
plt.plot(graph_x,marker=".")
plt.show()

# %%
data = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated.csv', encoding="utf-8")
data['end']=data['end'].astype(str)
data['left_bottom']=data['left_bottom'].astype(str)
data['mid_point']=data['mid_point'].astype(str)
data['right_bottom']=data['right_bottom'].astype(str)
data['start_point']=data['start_point'].astype(str)
data['end1']=data['end1'].astype(str)
data['left_bottom1']=data['left_bottom1'].astype(str)
data['mid_point1']=data['mid_point1'].astype(str)
data['right_bottom1']=data['right_bottom1'].astype(str)
data['start_point1']=data['start_point1'].astype(str)
data['x']=data['end']+","+data['left_bottom']+","+data['mid_point']+","+data['right_bottom']+","+data['start_point']+","+data['end1']+","+data['left_bottom1']+","+data['mid_point1']+","+data['right_bottom1']+","+data['start_point1']
data = data.drop(columns=['Unnamed: 0'])
data1=data[["x"]]
data1.to_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv')
data11 = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv', encoding = "utf-8")
data11 = data11.drop(columns=['Unnamed: 0'])
data11
data2 = pd.DataFrame(data11)
data2["first_x"] = data2["x"][1]
data2["first_x"][1:4] = ""
data2["x"].apply(lambda x: len(x.split(',')))
data3 = data2.drop(columns=['x'])
#data2['colon_count'] = data2.x.str.count(',')
#data2['colon_count'][0]
newx = data3["first_x"].str.split(",", n =9, expand = True)
data3["x_0"] = pd.to_numeric(newx[0])
data3["x_1"] = pd.to_numeric(newx[1])
data3["x_2"] = pd.to_numeric(newx[2])
data3["x_3"] = pd.to_numeric(newx[3])
data3["x_4"] = pd.to_numeric(newx[4])
data3["x_5"] = pd.to_numeric(newx[5])
data3["x_6"] = pd.to_numeric(newx[6])
data3["x_7"] = pd.to_numeric(newx[7])
data3["x_8"] = pd.to_numeric(newx[8])
data3["x_9"] = pd.to_numeric(newx[9])
data3 = data3.melt(id_vars = ["first_x"],
                 var_name = "xx",
                 value_name = "Value")
data3 = data3.sort_values(by = ["xx"])
data3 = data3.mask(data3.eq('None')).dropna()
data3['Value'].replace('',np.nan, inplace=True)
data3.dropna(subset=['Value'], inplace = True)
#data3
data3["xx"].value_counts()
graph_x = data3['Value'][0:20].tolist()
fig= plt.figure(figsize=(10, 5))
plt.title("Double Bottom")
plt.xticks(rotation=90)
plt.plot(graph_x,marker=".")
plt.show()

# %%
data = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated.csv', encoding="utf-8")
data.dtypes
# Out:
# Unnamed: 0         int64
# Num                int64
# date              object
# pattern           object
# pattern_name      object
# msecurity          int64
# colon_count        int64
# end_count          int64
# end                int64
# left_bottom        int64
# mid_point          int64
# right_bottom       int64
# start_point        int64
# target_price     float64
# end1               int64
# left_bottom1       int64
# mid_point1         int64
# right_bottom1      int64
# start_point1       int64
# target_price1    float64
# end2             float64
# left_bottom2     float64
# mid_point2       float64
# right_bottom2    float64
# start_point2     float64
# target_price2    float64
# end3             float64
# left_bottom3     float64
# mid_point3       float64
# right_bottom3    float64
# start_point3     float64
# target_price3    float64
# dtype: object

# %%
data = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated.csv', encoding="utf-8")
data['end']=data['end'].astype(str)
data['left_bottom']=data['left_bottom'].astype(str)
data['mid_point']=data['mid_point'].astype(str)
data['right_bottom']=data['right_bottom'].astype(str)
data['start_point']=data['start_point'].astype(str)
data['end1']=data['end1'].astype(str)
data['left_bottom1']=data['left_bottom1'].astype(str)
data['mid_point1']=data['mid_point1'].astype(str)
data['right_bottom1']=data['right_bottom1'].astype(str)
data['start_point1']=data['start_point1'].astype(str)
data['end2']=data['end2'].astype(str)
data['left_bottom2']=data['left_bottom2'].astype(str)
data['mid_point2']=data['mid_point2'].astype(str)
data['right_bottom2']=data['right_bottom2'].astype(str)
data['start_point2']=data['start_point2'].astype(str)
data['x']=data['end']+","+data['left_bottom']+","+data['mid_point']+","+data['right_bottom']+","+data['start_point']+","+data['end1']+","+data['left_bottom1']+","+data['mid_point1']+","+data['right_bottom1']+","+data['start_point1']+","+data['end2']+","+data['left_bottom2']+","+data['mid_point2']+","+data['right_bottom2']+","+data['start_point2']
data = data.drop(columns=['Unnamed: 0'])
data1=data[["x"]]

# %%
data = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated.csv', encoding="utf-8")
data['end']=data['end'].astype(str)
data['left_bottom']=data['left_bottom'].astype(str)
data['mid_point']=data['mid_point'].astype(str)
data['right_bottom']=data['right_bottom'].astype(str)
data['start_point']=data['start_point'].astype(str)
data['end1']=data['end1'].astype(str)
data['left_bottom1']=data['left_bottom1'].astype(str)
data['mid_point1']=data['mid_point1'].astype(str)
data['right_bottom1']=data['right_bottom1'].astype(str)
data['start_point1']=data['start_point1'].astype(str)
data['end2']=data['end2'].astype(str)
data['left_bottom2']=data['left_bottom2'].astype(str)
data['mid_point2']=data['mid_point2'].astype(str)
data['right_bottom2']=data['right_bottom2'].astype(str)
data['start_point2']=data['start_point2'].astype(str)
data['x']=data['end']+","+data['left_bottom']+","+data['mid_point']+","+data['right_bottom']+","+data['start_point']+","+data['end1']+","+data['left_bottom1']+","+data['mid_point1']+","+data['right_bottom1']+","+data['start_point1']+","+data['end2']+","+data['left_bottom2']+","+data['mid_point2']+","+data['right_bottom2']+","+data['start_point2']
data = data.drop(columns=['Unnamed: 0'])
data1=data[["x"]]
data1.to_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv')
data11 = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv', encoding = "utf-8")
data11 = data11.drop(columns=['Unnamed: 0'])
data11
data2 = pd.DataFrame(data11)
data2["first_x"] = data2["x"][2]
data2["first_x"][1:4] = ""
data2["x"].apply(lambda x: len(x.split(',')))
data3 = data2.drop(columns=['x'])
data3['first_x'][0]
#data2['colon_count'] = data2.x.str.count(',')
#data2['colon_count'][0]
#newx = data3["first_x"].str.split(",", n =14, expand = True)
#data3["x_0"] = pd.to_numeric(newx[0])
#data3["x_1"] = pd.to_numeric(newx[1])
#data3["x_2"] = pd.to_numeric(newx[2])
#data3["x_3"] = pd.to_numeric(newx[3])
#data3["x_4"] = pd.to_numeric(newx[4])
#data3["x_5"] = pd.to_numeric(newx[5])
#data3["x_6"] = pd.to_numeric(newx[6])
#data3["x_7"] = pd.to_numeric(newx[7])
#data3["x_8"] = pd.to_numeric(newx[8])
#data3["x_9"] = pd.to_numeric(newx[9])
#data3["xx_1"] = pd.to_numeric(newx[10])
#data3["xx_2"] = pd.to_numeric(newx[11])
#data3["xx_3"] = pd.to_numeric(newx[12])
#data3["xx_4"] = pd.to_numeric(newx[13])
#data3["xx_5"] = pd.to_numeric(newx[14])
#data3["xx_6"] = pd.to_numeric(newx[15])
#data3 = data3.melt(id_vars = ["first_x"],
#                 var_name = "xx",
#                 value_name = "Value")
#data3 = data3.sort_values(by = ["xx"])
#data3 = data3.mask(data3.eq('None')).dropna()
#data3['Value'].replace('',np.nan, inplace=True)
#data3.dropna(subset=['Value'], inplace = True)
#data3
#data3["xx"].value_counts()
#graph_x = data3['Value'][0:30].tolist()
#fig= plt.figure(figsize=(10, 5))
#plt.title("Double Bottom")
#plt.xticks(rotation=90)
#plt.plot(graph_x,marker=".")
#plt.show()
# Out:
# '1517961600000,1512604800000,1513296000000,1513900800000,1507852800000,1544486400000,1540512000000,1541548800000,1542240000000,1537488000000,1551398400000.0,1545782400000.0,1549497600000.0,1549929600000.0,1544486400000.0'

# %%
data = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated.csv', encoding="utf-8")
data['end']=data['end'].astype(str)
data['left_bottom']=data['left_bottom'].astype(str)
data['mid_point']=data['mid_point'].astype(str)
data['right_bottom']=data['right_bottom'].astype(str)
data['start_point']=data['start_point'].astype(str)
data['end1']=data['end1'].astype(str)
data['left_bottom1']=data['left_bottom1'].astype(str)
data['mid_point1']=data['mid_point1'].astype(str)
data['right_bottom1']=data['right_bottom1'].astype(str)
data['start_point1']=data['start_point1'].astype(str)
data['x']=data['end']+","+data['left_bottom']+","+data['mid_point']+","+data['right_bottom']+","+data['start_point']+","+data['end1']+","+data['left_bottom1']+","+data['mid_point1']+","+data['right_bottom1']+","+data['start_point1']
data = data.drop(columns=['Unnamed: 0'])
data1=data[["x"]]
data1.to_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv')
data11 = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv', encoding = "utf-8")
data11 = data11.drop(columns=['Unnamed: 0'])
data11
data2 = pd.DataFrame(data11)
data2["first_x"] = data2["x"][3]
data2["first_x"][1:4] = ""
data2["x"].apply(lambda x: len(x.split(',')))
data3 = data2.drop(columns=['x'])
#data2['colon_count'] = data2.x.str.count(',')
#data2['colon_count'][0]
newx = data3["first_x"].str.split(",", n =9, expand = True)
data3["x_0"] = pd.to_numeric(newx[0])
data3["x_1"] = pd.to_numeric(newx[1])
data3["x_2"] = pd.to_numeric(newx[2])
data3["x_3"] = pd.to_numeric(newx[3])
data3["x_4"] = pd.to_numeric(newx[4])
data3["x_5"] = pd.to_numeric(newx[5])
data3["x_6"] = pd.to_numeric(newx[6])
data3["x_7"] = pd.to_numeric(newx[7])
data3["x_8"] = pd.to_numeric(newx[8])
data3["x_9"] = pd.to_numeric(newx[9])
data3 = data3.melt(id_vars = ["first_x"],
                 var_name = "xx",
                 value_name = "Value")
data3 = data3.sort_values(by = ["xx"])
data3 = data3.mask(data3.eq('None')).dropna()
data3['Value'].replace('',np.nan, inplace=True)
data3.dropna(subset=['Value'], inplace = True)
#data3
data3["xx"].value_counts()
graph_x = data3['Value'][0:20].tolist()
fig= plt.figure(figsize=(10, 5))
plt.title("Double Bottom")
plt.xticks(rotation=90)
plt.plot(graph_x,marker=".")
plt.show()

# %%
data = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated.csv', encoding="utf-8")
data['end']=data['end'].astype(str)
data['left_bottom']=data['left_bottom'].astype(str)
data['mid_point']=data['mid_point'].astype(str)
data['right_bottom']=data['right_bottom'].astype(str)
data['start_point']=data['start_point'].astype(str)
data['end1']=data['end1'].astype(str)
data['left_bottom1']=data['left_bottom1'].astype(str)
data['mid_point1']=data['mid_point1'].astype(str)
data['right_bottom1']=data['right_bottom1'].astype(str)
data['start_point1']=data['start_point1'].astype(str)
data['x']=data['end']+","+data['left_bottom']+","+data['mid_point']+","+data['right_bottom']+","+data['start_point']+","+data['end1']+","+data['left_bottom1']+","+data['mid_point1']+","+data['right_bottom1']+","+data['start_point1']
data = data.drop(columns=['Unnamed: 0'])
data1=data[["x"]]
data1.to_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv')
data11 = pd.read_csv('D:\\Learning\\Time Series Analysis - Real time data\\Double_Bottom\\Double_Bottom_updated1_only_co-ordinates.csv', encoding = "utf-8")
data11 = data11.drop(columns=['Unnamed: 0'])
data11
data2 = pd.DataFrame(data11)
data2["first_x"] = data2["x"][4]
data2["first_x"][1:4] = ""
data2["x"].apply(lambda x: len(x.split(',')))
data3 = data2.drop(columns=['x'])
#data2['colon_count'] = data2.x.str.count(',')
#data2['colon_count'][0]
newx = data3["first_x"].str.split(",", n =9, expand = True)
data3["x_0"] = pd.to_numeric(newx[0])
data3["x_1"] = pd.to_numeric(newx[1])
data3["x_2"] = pd.to_numeric(newx[2])
data3["x_3"] = pd.to_numeric(newx[3])
data3["x_4"] = pd.to_numeric(newx[4])
data3["x_5"] = pd.to_numeric(newx[5])
data3["x_6"] = pd.to_numeric(newx[6])
data3["x_7"] = pd.to_numeric(newx[7])
data3["x_8"] = pd.to_numeric(newx[8])
data3["x_9"] = pd.to_numeric(newx[9])
data3 = data3.melt(id_vars = ["first_x"],
                 var_name = "xx",
                 value_name = "Value")
data3 = data3.sort_values(by = ["xx"])
data3 = data3.mask(data3.eq('None')).dropna()
data3['Value'].replace('',np.nan, inplace=True)
data3.dropna(subset=['Value'], inplace = True)
#data3
data3["xx"].value_counts()
graph_x = data3['Value'][0:20].tolist()
fig= plt.figure(figsize=(10, 5))
plt.title("Double Bottom")
plt.xticks(rotation=90)
plt.plot(graph_x,marker=".")
plt.show()
